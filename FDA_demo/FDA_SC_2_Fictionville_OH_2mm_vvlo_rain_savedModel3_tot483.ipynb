# %%
with open('./working_dir/xgbTup_070923_1.pkl', 'rb') as file:
    xgboost_model = pickle.load(file)
    
    print(xgboost_model)

# %%
import joblib
import pandas as pd
# import the API
APILoc = 'API/'

import sys
sys.path.insert(0, APILoc)

from API import *

# get aggregate data
targetDataLoc = '../data/ts_Fictionville_OH_18_vvlo_rain_stat.csv'
targetDf = pd.read_csv(targetDataLoc)
boostDataLoc = '../data/ts_Fictionville_OH_10_to_15_stat.csv'
boostDf = pd.read_csv(boostDataLoc)
targetDf.head()

xColumnsToKeep = ["radiation","rain", "avg_max_temp", "avg_min_temp"]
yColumnsToKeep = ["yield"]
test_xDf = targetDf[xColumnsToKeep]
boost_xDf = boostDf[xColumnsToKeep]
test_yDf = targetDf[yColumnsToKeep]
boost_yDf = boostDf[yColumnsToKeep]

# reset the index
xTest = test_xDf.reset_index(drop=True)
yTest = test_yDf.reset_index(drop=True)
boost_xDf = boost_xDf.reset_index(drop=True)
boost_yDf = boost_yDf.reset_index(drop=True)

all_years_Loc = '../data/ts_NB_OH_10_to_18_no15_no17_class_mv_idx_ylds.csv'
all_yearsDf = pd.read_csv(all_years_Loc)
final_year_Loc = '../data/NB_OH_avg_ylds_for_math_mv_10_to_16.csv'
final_yearDf = pd.read_csv(final_year_Loc)
final_yearDf.head()
target_year_Loc = '../data/ts_NB_OH_2018_ylds_mv_idx.csv'
target_yearDf = pd.read_csv(target_year_Loc)

model = joblib.load('working_dir/xgbTup_070923_3.pkl')
actualTest(all_yearsDf, final_yearDf, target_yearDf, boost_xDf, boost_yDf, xTest, yTest, model[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 39
#      36 target_year_Loc = '../data/ts_NB_OH_2018_ylds_mv_idx.csv'
#      37 target_yearDf = pd.read_csv(target_year_Loc)
# ---> 39 model = xgb.Booster(xgboost_model)
#      41 actualTest(all_yearsDf, final_yearDf, target_yearDf, boost_xDf, boost_yDf, xTest, yTest, model[0])
#
# File ~\PycharmProject\PYCS\.venv\Lib\site-packages\xgboost\core.py:1731, in Booster.__init__(self, params, cache, model_file)
#    1728     raise TypeError("Unknown type:", model_file)
#    1730 params = params or {}
# -> 1731 params_processed = _configure_metrics(params.copy())
#    1732 params_processed = self._configure_constraints(params_processed)
#    1733 if isinstance(params_processed, list):
#
# AttributeError: 'tuple' object has no attribute 'copy'
